# %%
# Create class "Student"
class Student:

    # Constructor
    def __init__(self, ma_sinh_vien, ho_ten, ngay_sinh, que_quan, chuyen_nganh, lop):
        self.ma_sinh_vien = ma_sinh_vien
        self.ho_ten = ho_ten
        self.ngay_sinh = ngay_sinh
        self.que_quan = que_quan
        self.chuyen_nganh = chuyen_nganh
        self.lop = lop

    # Function to display students' details
    def display(self, ob):
        print("Mã sinh viên:", ob.ma_sinh_vien)
        print("Họ tên:", ob.ho_ten)
        print("Ngày sinh:", ob.ngay_sinh)
        print("Quê quán:", ob.que_quan)
        print("Chuyên ngành:", ob.chuyen_nganh)
        print("Lớp:", ob.lop)
        print()
        
    # Function to create and append new student
    def accept(self):
        # use ' int(input()) ' method to take input from user
        ma_sinh_vien = input("Mã sinh viên: ")
        ho_ten = input("Họ tên: ")
        ngay_sinh = input("Ngày tháng năm sinh: ")
        que_quan = input("Quê quán: ")
        chuyen_nganh = input("Chuyên ngành: ")
        lop = input("Lớp: ")           
        ob = Student(ma_sinh_vien, ho_ten, ngay_sinh, que_quan, chuyen_nganh, lop)
        Student_List.append(ob)
        print()
        
    # Update Function
    def update(self):
        i = obj.search(msv)
        obj[i].ma_sinh_vien = input("Mã sinh viên: ")
        obj[i].ho_ten = input("Họ tên: ")
        obj[i].ngay_sinh = input("Ngày tháng năm sinh: ")
        obj[i].que_quan = input("Quê quán: ")
        obj[i].chuyen_nganh = input("Chuyên ngành: ")
        obj[i].lop = input("Lớp: ")
        
    # Delete Function
    def delete(self, ma_sinh_vien):
        i = obj.search(ma_sinh_vien)
        del Student_List[i]

    # Search Function
    def search(self, ob):
        msv = input("Nhập mã sinh viên cần tìm: ")
        for i in range(Student_List.__len__()):
            if(Student_List[i].ma_sinh_vien == msv):
                ob.display(Student_List[i])
        return "Không tìm thấy mã sinh viên!"
            
    # Sort Function
    def sort(self, ma_sinh_vien):
        pass

# An object of Student class
obj = Student(0, 0, 0, 0, 0, 0)

print("""1. Xem danh mục sinh viên
2. Thêm sinh viên mới vào danh mục
3. Cập nhật thông tin của sinh viên trong danh mục
4. Xóa thông tin sinh viên khỏi danh mục
5. Tìm kiếm thông tin sinh viên trong danh mục theo từ khóa
6. Sắp xếp thông tin sinh viên trong danh mục
7. Thoát chương trình""")
print()

while True:
    choice = int(input("Lựa chọn của bạn: "))
    print()
    
    if(choice == 1):
        for i in range(Student_List.__len__()):
            obj.display(Student_List[i])

    elif(choice == 2):                                               
        obj.accept()
        
    elif(choice == 3):
        msv = input("Nhập mã sinh viên cần cập nhật thông tin: ")
        obj.update()
        
        
    elif(choice == 4):
        obj.delete(2)
        print(Student_List.__len__())
        print("List after deletion")
        for i in range(Student_List.__len__()):
            obj.display(Student_List[i])
        
    elif(choice == 5):
        obj.search(Student_List[i])

    elif(choice == 6):
        pass
            
    else:
        print("Cảm ơn bạn đã sử dụng chương trình !")
        break
# Out:
# 1. Xem danh mục sinh viên
# 2. Thêm sinh viên mới vào danh mục
# 3. Cập nhật thông tin của sinh viên trong danh mục
# 4. Xóa thông tin sinh viên khỏi danh mục
# 5. Tìm kiếm thông tin sinh viên trong danh mục theo từ khóa
# 6. Sắp xếp thông tin sinh viên trong danh mục
# 7. Thoát chương trình
#
# Lựa chọn của bạn: 1
#
# Mã sinh viên: 1210229
# Họ tên: Phan Trần Bảo Tuấn
# Ngày sinh: 08/04/1994
# Quê quán: Lâm Đồng
# Chuyên ngành: Công nghệ kỹ thuật điện tử, truyền thông
# Lớp: VTK36
#
# Lựa chọn của bạn: 3
#
# Nhập mã sinh viên cần cập nhật thông tin: 1210229

# %%
# Create a list to add Students
Student_List = []
